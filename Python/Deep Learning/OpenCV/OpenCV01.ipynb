# %%
# !pip install opencv-python opencv-contrib-python
# Out:
# ...
# WARNING: Ignoring invalid distribution -otebook (c:\users\gjaischool1\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -otebook (c:\users\gjaischool1\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -otebook (c:\users\gjaischool1\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -otebook (c:\users\gjaischool1\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -otebook (c:\users\gjaischool1\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -otebook (c:\users\gjaischool1\anaconda3\lib\site-packages)

# %%
# opencv 설치 확인
import cv2

# 버전 확인
print(cv2.__version__)
# Out:
# 4.8.1

# %%
import cv2

# 이미지 읽기
img = cv2.imread("./images/bears.png")

# 새창에 이미지 출력
cv2.imshow("test", img)

cv2.waitKey(0)

cv2.destroyAllWindows()

# %% [markdown]
# - matplotlib를 이용하여 이미지 출력

# %%
import matplotlib.pyplot as plt

plt.imshow(img)
plt.show()

# %%
#R<-> B변경
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(img)
# 눈금 삭제
plt.xticks([])
plt.yticks([])

plt.show()

# %% [markdown]
# ## Widget를 이용해서 이미지 출력하기
# - 브라우저 화면에 이미지나 동영상을 출력할 때 유용

# %%
# !pip install ipywidgets
# Out:
# ...
# WARNING: Ignoring invalid distribution -otebook (c:\users\gjaischool1\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -otebook (c:\users\gjaischool1\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -otebook (c:\users\gjaischool1\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -otebook (c:\users\gjaischool1\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -otebook (c:\users\gjaischool1\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -otebook (c:\users\gjaischool1\anaconda3\lib\site-packages)

# %%
import ipywidgets as wid
from IPython.display import display
import cv2

img = cv2.imread("./images/bears.png")

# 이미지를 출력할 위젯 생성
h, w, c = img.shape

# Image 위젯 설정(이미지 타입, 크기)
img_wid = wid.Image(format="jpeg", width=w, height=h)

# 위젯 출력
display(img_wid)

# 위젯에 읽은 이미지를 출력
# 배열로 된 이미지를 JPG 타입으로 변환
_, en_img = cv2.imencode(".jpeg", img)

# 위젯에 변환된 이미지 전송 - byte 단위로 전송
img_wid.value = en_img.tobytes()
# Out:
# Image(value=b'', format='jpeg', height='170', width='297')
